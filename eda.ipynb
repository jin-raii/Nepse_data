# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv( '/home/rajesh/nepse_data/nepse-data/data/02_15_2025.csv')
df.head()
# Out:
#       Transact. No. Symbol  Buyer  Seller Quantity    Rate    Amount
# 0  2025021305016233    BBC     96      14       10  5587.0   55870.0
# 1  2025021305015830    BBC     22       1       30  5520.0  165600.0
# 2  2025021305015829    BBC      6       1       10  5522.0   55220.0
# 3  2025021305015828    BBC     26       1       10  5523.0   55230.0
# 4  2025021305015827    BBC     57       1       10  5523.0   55230.0

# %% [markdown]
# ### data info

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Transact. No.         Buyer        Seller          Rate        Amount
# count   7.882500e+04  78825.000000  78825.000000  78825.000000  7.882500e+04
# mean    2.025021e+15     43.430511     42.313961    721.127889  1.004868e+05
# std     1.473505e+06     21.361483     21.251647    735.866283  3.271215e+05
# min     2.025021e+15      1.000000      1.000000      8.320000  1.988000e+02
# 25%     2.025021e+15     28.000000     28.000000    413.000000  1.225770e+04
# 50%     2.025021e+15     44.000000     43.000000    605.000000  3.925000e+04
# 75%     2.025021e+15     58.000000     57.000000    815.500000  1.049010e+05
# max     2.025021e+15    101.000000    101.000000  47400.000000  3.865890e+07

# %%
print(f"Symbol Count : {len(df['Symbol'].unique())}")
# Out:
# Symbol : 300

# %%
sns.scatterplot(data=df, x='Seller', y='Rate')
# Out:
# <Axes: xlabel='Seller', ylabel='Rate'>

# %%
sns.scatterplot(data=df, x='Buyer', y='Rate')
# Out:
# <Axes: xlabel='Buyer', ylabel='Rate'>
